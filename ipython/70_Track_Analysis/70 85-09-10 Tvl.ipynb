# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-09-10 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'259.1',
#  u'260.1',
#  u'261.1',
#  u'262.1',
#  u'263.1',
#  u'264.1',
#  u'265.1',
#  u'266.1',
#  u'267.1',
#  u'268.1',
#  u'269.1',
#  u'270.1',
#  u'271.1',
#  u'272.1',
#  u'273.1',
#  u'274.1',
#  u'275.1',
#  u'276.1',
#  u'277.1',
#  u'278.1',
#  u'279.1',
#  u'280.1',
#  u'281.1',
#  u'282.1',
#  u'283.1',
#  u'284.1',
#  u'285.1',
#  u'286.1',
#  u'287.1']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0   259.1   9.195991  6.208507       30.270038      53.041261
# 1   260.1  10.205734  9.823585       33.073964      52.814865
# 2   261.1  16.946798  4.620022       10.027382       5.737618
# 3   262.1  12.647710  5.712577       13.596510      10.565166
# 4   263.1  16.401193  6.358045       13.927551      11.377826
# 5   264.1  12.066872  8.535728       38.308523      38.212628
# 6   265.1  16.194651  4.419920       28.424390      28.076189
# 7   266.1  15.110984  2.550632       27.949207      20.321197
# 8   267.1   9.081682  4.622757       16.862080      21.876508
# 9   268.1  12.024066  2.075614       15.414182      18.680067
# 10  269.1  13.222680  6.316872       13.135548      17.286753
# 11  270.1  10.719448  4.713541       16.086137      18.615447
# 12  271.1  10.236880  4.579396       26.622348      22.401772
# 13  272.1  16.520562  6.648642       12.502257       9.376751
# 14  273.1  16.965686  9.610162       23.814874      23.996131
# 15  274.1  12.811879  6.406490       11.350945       8.328404
# 16  275.1  10.422370  7.960066        6.324826       5.893336
# 17  276.1  10.285597  5.715354       23.971310      23.628986
# 18  277.1   4.720901  3.725377        8.897956      22.996714
# 19  278.1  13.772367  5.611214       14.246932      11.912246
# 20  279.1   7.774665  4.963529       19.300833      25.966301
# 21  280.1  11.630487  5.184949       26.216307      24.377496
# 22  281.1   8.082354  5.486863       49.871098      48.448051
# 23  282.1  16.952321  4.573700       16.295224       9.697408
# 24  283.1  10.261972  5.942822       23.164160      27.268905
# 25  284.1  15.162106  3.023079       10.028739       9.830805
# 26  285.1  11.741489  5.647160       25.563620      24.556822
# 27  286.1  13.358100  4.734072       19.337569      23.013167
# 28  287.1   8.590772  5.981007       21.947445      21.727412
