# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-02-20 lab 2.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA043',
#  u'SNA044',
#  u'SNA045',
#  u'SNA046',
#  u'SNA047',
#  u'SNA048',
#  u'SNA049',
#  u'SNA050',
#  u'SNA051']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  SNA043  11.504607  4.539097       16.349351      21.484444
# 1  SNA044  14.391223  6.918238       22.414075      30.334086
# 2  SNA045   9.825292  2.879774        8.701794       7.092117
# 3  SNA046   7.093944  4.477299       27.279086      32.666274
# 4  SNA047  11.664225  4.924974       18.822183      32.190342
# 5  SNA048  10.415067  2.242138        7.591916       6.414721
# 6  SNA049  16.692997  4.902413        5.310141       3.463938
# 7  SNA050  19.065636  2.684722        4.011307       3.916287
# 8  SNA051   8.152991  2.311282        7.455492       7.024247
