# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

file = r'../data/ANALYSIS/84-10-22 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA005',
#  u'SNA006',
#  u'SNA007',
#  u'SNA008',
#  u'SNA009',
#  u'SNA010',
#  u'SNA011',
#  u'SNA012',
#  u'SNA013',
#  u'SNA014',
#  u'SNA015',
#  u'SNA016',
#  u'SNA017',
#  u'SNA018']

# %%
fig, axes = plt.subplots(nrows=14, ncols=3, figsize=(20, 45))

position = 0

for key in df.keys():
    df[key].plot(x='X-location.1', y='Y-location.1', ax=axes[position, 0])
    df[key].plot(y='Distance', ax=axes[position, 1])
    df[key].plot(y='Abs Angle', ax=axes[position, 2])
    position = position + 1
