# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/84-10-19 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA001', u'SNA002', u'SNA003']

# %%
plot_tracks(df)

# %%
summary = summary_stats(df)
summary
# Out:
#     Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  SNA001  21.232716  7.771374       16.707172      13.054351
# 1  SNA002   7.414347  3.687749       18.805887      16.236216
# 2  SNA003  13.655274  6.567902       29.889479      42.846557

# %%
df['SNA001']['Distance'].max()
# Out:
# 33.4934321919985
