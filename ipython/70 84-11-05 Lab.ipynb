# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

file = r'../data/ANALYSIS/84-11-05 lab.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA019',
#  u'SNA020',
#  u'SNA021',
#  u'SNA022',
#  u'SNA023',
#  u'SNA024',
#  u'SNA025',
#  u'SNA025B',
#  u'SNA026',
#  u'SNA027',
#  u'SNA028',
#  u'SNA029']

# %%
fig, axes = plt.subplots(nrows=12, ncols=3, figsize=(20, 45))

position = 0

for key in df.keys():
    df[key].plot(x='X-location.1', y='Y-location.1', ax=axes[position, 0])
    df[key].plot(y='Distance', ax=axes[position, 1])
    df[key].plot(y='Abs Angle', ax=axes[position, 2], ylim=(0, 180))
    position = position + 1

# %%
summary_df = pd.DataFrame()

for key in df.keys():
    summary_df['Name'].append(key)
#    summary_df['Mean Distance'] = df[key]['Distance'].mean()
#    summary_df['Std Distance'] = df[key]['Distance'].std()
    
summary_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-81bd51bdc5c3> in <module>()
#       2
#       3 for key in df.keys():
# ----> 4     summary_df['Name'].append(key)
#       5 #    summary_df['Mean Distance'] = df[key]['Distance'].mean()
#       6 #    summary_df['Std Distance'] = df[key]['Distance'].std()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
# ...
