# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-07-29 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'221.1',
#  u'222.1',
#  u'223.1',
#  u'224.1',
#  u'225.1',
#  u'226.1',
#  u'227.1',
#  u'228.1']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#    Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  221.1  10.408139  4.171751       18.629243      13.914685
# 1  222.1  11.905039  5.052235       30.596385      23.159474
# 2  223.1  14.681795  8.823898       18.636446      19.147987
# 3  224.1  12.926956  6.237811       29.364984      26.604760
# 4  225.1  17.775833  4.983272       19.369530      17.898321
# 5  226.1   9.563362  5.650964       33.377501      29.544266
# 6  227.1   7.813975  3.493307       30.359968      24.739606
# 7  228.1   6.873695  2.977369       20.200464      23.339719
