# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-05-01 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'132',
#  u'133',
#  u'134',
#  u'135',
#  u'136',
#  u'137',
#  u'138',
#  u'139',
#  u'140',
#  u'141',
#  u'142',
#  u'143',
#  u'144',
#  u'145',
#  u'146',
#  u'147',
#  u'148',
#  u'149',
#  u'150',
#  u'151',
#  u'152',
#  u'153',
#  u'154',
#  u'155',
#  u'156',
#  u'157',
#  u'158',
#  u'159']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#    Track  Mean_Dist   Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0    132  16.899163   6.983173       26.326770      21.701992
# 1    133  13.625582   9.199592       40.599875      33.415450
# 2    134  16.874665   9.297823       44.328597      35.292098
# 3    135  10.738950   4.225017       28.280852      29.813824
# 4    136  11.716503   4.629734       40.608467      34.722363
# 5    137  17.574410   9.033734       29.637545      19.356549
# 6    138  48.037032  18.390527       29.592555      32.027998
# 7    139  10.239292   4.013105       30.974697      27.873363
# 8    140  13.986460   5.390843       35.907477      29.511867
# 9    141  13.898293   4.823677       40.666989      31.127195
# 10   142  17.517158   8.175845       21.735039      29.014603
# 11   143  13.434470   5.229731       38.791125      31.309422
# 12   144  12.994784   7.041874       30.463759      24.947626
# 13   145  10.894477   7.317817       39.150407      44.051968
# 14   146  12.732192   6.461531       26.887419      26.098479
# 15   147   9.917300   7.021464       26.023183      25.536725
# 16   148  21.662923  11.803444       30.432940      32.795647
# 17   149  31.957736  11.834025       38.622250      26.983731
# 18   150  14.862767   6.633992       33.232460      27.188971
# 19   151  14.205962   5.289996       39.867148      35.130093
# 20   152  12.360744   5.253111       32.803971      28.834677
# 21   153  12.591549   7.371225       41.629855      41.390300
# 22   154  15.476579   4.137366       13.863353      15.840907
# 23   155  17.307301   9.467601       42.708938      29.411721
# 24   156  11.381830   6.974765       28.078937      27.052839
# 25   157  15.561613   4.735554       43.014453      31.688107
# 26   158  13.840739   5.503006       31.875169      28.240566
# 27   159  11.613000   5.416603       35.358645      34.279109
