# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-06-12 mar.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'160',
#  u'161',
#  u'162',
#  u'163',
#  u'164',
#  u'165',
#  u'166',
#  u'167',
#  u'168',
#  u'169',
#  u'170',
#  u'171',
#  u'172',
#  u'173']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#    Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0    160  10.445655  4.356055        9.105737       8.324374
# 1    161   3.880661  4.459317       38.548848      54.420052
# 2    162  15.572186  2.035641       11.276152       9.106761
# 3    163  10.359895  5.270985       29.004817      27.501070
# 4    164  14.664489  3.216898       20.836488      15.537745
# 5    165  11.396033  3.401392       34.696644      25.517227
# 6    166   7.587538  2.467913       26.035416      29.071020
# 7    167  11.457852  3.883204       27.728935      19.836892
# 8    168  16.886869  5.489622       31.297713      24.175070
# 9    169  10.359553  2.598601       13.267778      13.894422
# 10   170  13.119866  4.206626       25.236283      20.939333
# 11   171   5.024619  3.911579       32.274078      48.990773
# 12   172   6.624008  2.960529       49.498506      46.758968
# 13   173  10.211284  4.306959       30.292700      27.244508
