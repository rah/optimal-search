# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

file = r'../data/ANALYSIS/84-10-20 tvl.xls'
df = pd.read_excel(file, sheetname=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA004']

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))

df['SNA004'].plot(x='X-location.1', y='Y-location.1', ax=axes[0])
df['SNA004'].plot(y='Distance', ax=axes[1])
df['SNA004'].plot(y='Abs Angle', ax=axes[2])
