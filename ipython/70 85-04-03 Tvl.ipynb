# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-04-03 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'117',
#  u'118',
#  u'119',
#  u'120',
#  u'121',
#  u'122',
#  u'123',
#  u'124',
#  u'125',
#  u'126',
#  u'127',
#  u'128',
#  u'129',
#  u'130',
#  u'131']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#    Track  Mean_Dist   Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0    098   9.688995   5.910687       43.942323      35.009561
# 1    099   9.557368   8.133329       27.475108      28.666211
# 2    100  11.702730   8.374991       27.919288      37.030819
# 3    101  17.653418  12.725061       24.333674      34.915041
# 4    102  23.632896   8.397300       62.905559      23.389497
# 5    103   8.865802   6.742823       20.938848      28.312266
# 6    104  21.643891   7.257734        5.029581       4.506018
# 7    105  10.519388   7.009972       29.848171      32.516987
# 8    106   7.508743   5.425566       31.787287      36.857148
# 9    107   6.405277   6.325722       43.738211      49.950533
# 10   108   8.369347   5.664601       31.824067      29.575931
# 11   109  10.909837   6.388018       31.117119      37.839502
# 12   110   5.373895   2.682021       19.118220      23.081749
# 13   111  14.187276   7.633470       15.874049      18.225264
# 14   112  14.267714   9.374941       30.553085      34.350207
# 15   113  19.001538   9.691643       22.022244      19.609799
# 16   114   7.757890  12.642767       16.503141      21.982588
# 17   115   6.873220   3.093498       15.401302      14.947473
# 18   116  18.091923  32.172521       15.661894      16.918781
