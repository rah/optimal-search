# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-08-14 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'229.1',
#  u'230.1',
#  u'231.1',
#  u'232.1',
#  u'233.1',
#  u'234.1',
#  u'235.1',
#  u'236.1',
#  u'237.1',
#  u'238.1',
#  u'239.1',
#  u'240.1',
#  u'241.1',
#  u'242.1',
#  u'243.1']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0   229.1  18.411682  4.986894       13.292258       9.824717
# 1   230.1  19.140767  5.641443       33.690188      31.674209
# 2   231.1   9.925603  3.915305       13.195308      13.345812
# 3   232.1  16.896244  5.107981       32.866207      28.577071
# 4   233.1  21.010112  8.189654       27.106883      31.168530
# 5   234.1  21.300693  7.632111       24.981364      25.424948
# 6   235.1  20.281608  3.199465       12.197294      12.230812
# 7   236.1  22.457281  5.256170       26.182038      24.996876
# 8   237.1  16.949581  7.868423       43.697382      33.859742
# 9   238.1  20.031024  2.937031        9.414541       7.969958
# 10  239.1  19.238261  8.045572       33.208202      32.568535
# 11  240.1  13.859347  4.192058       31.402433      24.917526
# 12  241.1  16.423708  3.713787       35.462988      31.947206
# 13  242.1   9.576115  3.630953       17.107290      15.877382
# 14  243.1  12.572398  5.021950       46.119534      36.873819
