# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/84-11-12 lab.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA031', u'SNA032', u'SNA034', u'SNA035', u'SNA036', u'SNA037']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  SNA031   0.240251  0.146399       13.802238      13.024607
# 1  SNA032   0.299770  0.109027       17.192521      34.685597
# 2  SNA034   0.196487  0.110924       12.923005      17.190531
# 3  SNA035   0.244489  0.151008       30.929796      36.827424
# 4  SNA036   0.222438  0.138388       38.115418      49.171220
# 5  SNA037   0.226204  0.108596       29.411340      33.746196
