# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/84-12-23 mar.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA038', u'SNA039', u'SNA040', u'SNA041', u'SNA042']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist   Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  SNA038  14.415320   4.884175       29.718346      22.446811
# 1  SNA039  15.222053   6.130064       31.860834      30.870147
# 2  SNA040  18.631930   7.879924       25.217044      33.389493
# 3  SNA041  17.537615   6.175667       20.766649      19.314429
# 4  SNA042  19.293643  13.471416       18.815268      18.767575
