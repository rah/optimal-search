# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-07-16 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'215.1', u'216.1', u'217.1', u'218.1', u'219.1', u'220.1']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#    Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  215.1  15.334050  6.072701       18.353925      13.818238
# 1  216.1  16.915646  5.754887       33.562704      29.601954
# 2  217.1  14.660663  6.385795       12.587141      12.256246
# 3  218.1  18.386347  7.840762       43.511181      31.708211
# 4  219.1  15.136279  4.448600       16.636884      18.974693
# 5  220.1  12.005043  5.905505       34.446023      31.951235
