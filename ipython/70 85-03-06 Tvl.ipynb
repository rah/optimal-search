# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-03-06 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA052', u'SNA053', u'SNA054', u'SNA055', u'SNA056', u'SNA057', u'SNA058']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist   Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  SNA052  13.716322   7.541516       22.365370      18.491139
# 1  SNA053   9.852310   6.364217       29.134998      33.343072
# 2  SNA054  15.894934   7.164250       28.807294      26.175256
# 3  SNA055  13.952474  12.525504       44.351573      40.804244
# 4  SNA056  20.476290   9.274732       18.050703      11.241900
# 5  SNA057  10.903414   6.964423       34.263662      30.685334
# 6  SNA058  11.152610   6.436394       41.258268      48.651058
