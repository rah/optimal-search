# %%
import pandas as pd

DATA = '../data/tracks.csv'
df = pd.read_csv(DATA)

df.head(15)
# Out:
#      id      date time_start time_finish  species  prey location  pred_size  \
# 0   001  19-10-84      10:41       10:56        2     2       T6        NaN
# 1   002  19-10-84      11:06       11:20        2     2       T6        NaN
# 2   003  19-10=84      10:20       10:29        2     2       T6        NaN
# 3   004  20-10-84      10:10       11:00        1     1       T1        NaN
# 4   005  22-10-84      11:23       11:35        1     1       T1        1.2
# 5   006  22-10-84      11:45       11:55        1     1       T1        1.4
# 6   007  22-10-84      10:59       11:10        1     1       T1        1.2
# 7   008  22-10-84      12:17       12:23        1     1       T1        NaN
# 8   009  22-10-84      12:06       12:14        1     1       T1        NaN
# 9   010  24-10-84      14:13       14:29        1     1       T1        NaN
# 10  011  24-10-84      13:56       14:09        1     1       T1        NaN
# ...
