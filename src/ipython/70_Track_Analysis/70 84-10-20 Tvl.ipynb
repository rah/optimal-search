# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/84-10-20 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA004']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0  SNA004   0.406414  0.113782       30.472124      23.720285
