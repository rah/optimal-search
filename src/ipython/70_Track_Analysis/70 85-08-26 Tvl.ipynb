# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-08-26 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'244.1',
#  u'245.1',
#  u'246.1',
#  u'247.1',
#  u'248.1',
#  u'249.1',
#  u'250.1',
#  u'251.1',
#  u'252.1',
#  u'253.1',
#  u'254.1',
#  u'255.1',
#  u'256.1',
#  u'257.1',
#  u'258.1']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist   Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0   244.1  17.580399   5.578399       20.486849      15.441998
# 1   245.1  12.881824   4.438652       30.171245      33.103548
# 2   246.1  15.925490   4.506489       19.882232      16.973378
# 3   247.1  15.334666   9.002849       32.322150      28.483652
# 4   248.1  10.438072   7.630742       10.444427       8.148602
# 5   249.1  18.458223  13.865563       44.043709      36.968397
# 6   250.1  11.974070   1.476983       20.738680      17.149343
# 7   251.1  16.773951   7.174442       36.237946      30.720483
# 8   252.1  14.217088   5.249743       22.106913      21.466592
# 9   253.1  13.544384   5.269464       39.027488      35.942066
# 10  254.1  11.516093   4.145144       20.700614      20.704786
# 11  255.1  14.150782   4.325767       35.134469      28.870182
# 12  256.1  14.677816   4.627876       40.000711      30.082982
# 13  257.1  15.140659   5.187072       30.606242      29.808504
# 14  258.1  17.855164   2.470464       15.135860      11.355134
