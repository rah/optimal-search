# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-06-28 mar.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'201.1',
#  u'202.1',
#  u'203.1',
#  u'204.1',
#  u'205.1',
#  u'206.1',
#  u'207.1',
#  u'208.1',
#  u'209.1',
#  u'210.1',
#  u'211.1',
#  u'212.1',
#  u'213.1',
#  u'214.1']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#     Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0   174.1   6.525821  3.893450       23.350394      20.846766
# 1   175.1   8.675532  4.137044       47.674560      38.340621
# 2   176.1   7.922944  3.260697       20.967700      35.712781
# 3   177.1  10.069195  2.691168       33.688144      25.037109
# 4   178.1  17.142449  4.114477       11.865511       9.836469
# 5   179.1  13.503740  4.601970       35.007381      30.946611
# 6   180.1  14.740817  4.166031       17.533008      16.066672
# 7   181.1  15.402969  3.212216       20.769160      21.179289
# 8   182.1  19.033042  2.887932       52.984001      40.220622
# 9   183.1   7.905582  3.407184       12.508430      12.941423
# 10  184.1   9.681955  6.285719       39.297531      34.296708
# 11  185.1  10.469930  2.169927       13.012571       9.937058
