# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/84-10-22 tvl.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA005',
#  u'SNA006',
#  u'SNA007',
#  u'SNA008',
#  u'SNA009',
#  u'SNA010',
#  u'SNA011',
#  u'SNA012',
#  u'SNA013',
#  u'SNA014',
#  u'SNA015',
#  u'SNA016',
#  u'SNA017',
#  u'SNA018']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#      Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0   SNA005   0.336848  0.168252       29.270843      27.531830
# 1   SNA006   0.366152  0.108461       24.061142      19.716647
# 2   SNA007   0.215671  0.094023       13.916055      12.896732
# 3   SNA008   0.327560  0.139943       39.729501      27.568299
# 4   SNA009   0.318777  0.128544       29.566939      23.733736
# 5   SNA010   0.273325  0.111165       28.003282      28.783712
# 6   SNA011   0.261765  0.094941       26.621526      19.754580
# 7   SNA012   0.315299  0.105401       22.297895      20.084018
# 8   SNA013   0.392578  0.149948       17.178187      14.613470
# 9   SNA014   0.449190  0.142542       13.235826      10.619751
# 10  SNA015   0.425320  0.126218       20.113042      16.028594
# 11  SNA016   0.371070  0.144710       20.932822      17.261843
# 12  SNA017   0.368762  0.092206       16.340349      11.678056
# 13  SNA018   0.569093  0.157618       22.662893      19.177660
