# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from track_lib.track_util import summary_stats, plot_tracks

file = r'../data/ANALYSIS/85-03-10 lab.xls'
df = pd.read_excel(file, sheet_name=None, header=0, skiprows=[1])
df.keys()
# Out:
# [u'SNA059',
#  u'SNA060',
#  u'SNA061',
#  u'SNA062',
#  u'SNA063',
#  u'SNA064',
#  u'SNA065',
#  u'SNA066',
#  u'SNA067',
#  u'SNA068',
#  u'SNA069',
#  u'SNA070',
#  u'SNA071',
#  u'SNA072',
#  u'SNA073',
#  u'SNA074',
#  u'SNA075',
#  u'SNA076',
#  u'SNA078',
#  u'SNA079',
#  u'SNA080',
#  u'SNA081',
#  u'SNA082',
#  u'SNA083',
#  u'SNA084',
#  u'SNA085',
#  u'SNA086',
#  u'SNA087',
#  u'SNA088',
#  u'SNA089',
#  u'SNA090',
#  u'SNA091',
#  u'SNA092',
#  u'SNA093',
#  u'SNA094',
#  u'SNA095',
#  u'SNA096',
#  u'SNA097']

# %%
plot_tracks(df)

# %%
summary_stats(df)
# Out:
#      Track  Mean_Dist  Std_Dist  Mean_Abs_Angle  Std_Abs_Angle
# 0   SNA059  16.802275  7.343629       25.368061      43.933313
# 1   SNA060  18.370027  5.758065       10.254184       7.980726
# 2   SNA061  15.714380  4.255174       13.436607      21.493892
# 3   SNA062  17.374657  4.786945       14.088786       9.616621
# 4   SNA063  16.793453  4.071936        7.287860       4.740751
# 5   SNA064  18.636807  2.309548        9.034336       7.394192
# 6   SNA065  15.946159  2.810785        9.770623       7.443331
# 7   SNA066  16.189570  4.298222        9.523530       8.019392
# 8   SNA067  20.907216  3.513347       10.874436       8.009953
# 9   SNA068  17.129916  2.865327        9.234687       9.397563
# 10  SNA069  16.852689  6.991496       10.119945       8.849212
# 11  SNA070  17.368915  4.955169        8.244693       5.912348
# 12  SNA071  20.707067  3.155346        7.788349       5.061144
# 13  SNA072  15.683749  3.972186       11.688373       7.962549
# 14  SNA073  21.395013  3.790162        9.765556       4.413167
# 15  SNA074  14.521703  3.877756        8.440560       6.485294
# 16  SNA075  21.299208  3.988113        7.134748       5.047824
# 17  SNA076  16.819814  4.195863        7.864406       4.867330
# 18  SNA078  17.521532  3.321812        8.875827       8.603625
# 19  SNA079  11.394878  3.001185       10.780950      10.703699
# 20  SNA080  14.143898  4.251160        8.790059      13.420971
# 21  SNA081  15.026487  3.299178        9.703046       8.248884
# 22  SNA082  17.283119  2.904092        8.910046       7.134482
# 23  SNA083  16.629367  2.719285        7.470611       5.528266
# 24  SNA084  15.605434  3.718779       11.705375      10.597652
# 25  SNA085  18.018743  4.015566        9.095970       6.245104
# 26  SNA086  13.367109  6.470769        9.300744       8.694955
# 27  SNA087  13.995602  4.605026       15.059721      12.677319
# 28  SNA088  10.856110  3.654741       20.320360      16.264139
# 29  SNA089  16.683647  3.404221        8.697268       5.951619
# 30  SNA090  15.807274  5.105160       23.433495      39.842657
# 31  SNA091  14.640092  3.606221        9.163329       6.243689
# 32  SNA092  15.747644  5.026979        7.536368       5.666073
# 33  SNA093  16.075010  3.964401        8.177518       5.892310
# 34  SNA094  15.304305  4.074267        6.652726       6.804847
# 35  SNA095  17.938217  2.789565        8.731781       6.362353
# 36  SNA096  13.291723  3.787370        8.482151       4.761416
# 37  SNA097  15.783898  2.663023        9.179497       5.119733
